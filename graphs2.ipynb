# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("DF_EW1(ALL).csv")
df.shape
# Out:
# (407910, 42)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'EQYr', 'EQMon',
#        'EQDay', 'EQHH', 'EQMM', 'EQSS', 'EQLat', 'EQLong', 'EQDepth', 'EQMag',
#        'STNCode', 'STNLat', 'STNLong', 'STNH', 'recYr', 'recMon', 'recDay',
#        'recHH', 'recMM', 'recSS', 'fsamp', 'recDur', 'ScFactor', 'recfilename',
#        'EventID', 'PGA(m/s**2)', 'PGV (m/s)', 'PGD(m)', 'fc_low', 'fc_high',
#        'Arias Intensity(m/s)', 'CAV(m/s)', 'Dur_5_75_EW1', 'Dur_5_95_EW1',
#        'Dur_2_80_EW1', 'epic_distance(km)', 'Hypo_dis(km)', 'Vs30', 'f0, HV'],
#       dtype='object')

# %%
df1=df.drop(columns=['Unnamed: 0', 'Unnamed: 0.1','Unnamed: 0.1.1'])

# %%
df1
# Out:
#         EQYr  EQMon  EQDay  EQHH  EQMM  EQSS   EQLat   EQLong  EQDepth  EQMag  \
# 0       2000      1      6    13    53     0  35.843  139.247      9.0    2.9
# 1       2000      1      9    13     2     0  37.273  141.703     46.0    5.0
# 2       2000      1      9    22    41     0  36.547  139.367     14.0    3.3
# 3       2000      1     12    11     9     0  36.450  140.590     58.0    4.4
# 4       2000      1     24    21    50     0  37.128  141.567     46.0    4.5
# ...      ...    ...    ...   ...   ...   ...     ...      ...      ...    ...
# 407905  2016     11     21     8    35     0  34.777  136.405     14.0    3.2
# 407906  2016     11     22     5    59     0  37.353  141.603     25.0    7.4
# 407907  2016     11     22     6    21     0  34.720  137.023     15.0    3.3
# 407908  2016     12      6     9     5     0  36.007  137.343      5.0    4.5
# 407909  2016     12     28    21    38     0  36.720  140.573     11.0    6.3
#
# ...

# %%
df1.columns
# Out:
# Index(['EQYr', 'EQMon', 'EQDay', 'EQHH', 'EQMM', 'EQSS', 'EQLat', 'EQLong',
#        'EQDepth', 'EQMag', 'STNCode', 'STNLat', 'STNLong', 'STNH', 'recYr',
#        'recMon', 'recDay', 'recHH', 'recMM', 'recSS', 'fsamp', 'recDur',
#        'ScFactor', 'recfilename', 'EventID', 'PGA(m/s**2)', 'PGV (m/s)',
#        'PGD(m)', 'fc_low', 'fc_high', 'Arias Intensity(m/s)', 'CAV(m/s)',
#        'Dur_5_75_EW1', 'Dur_5_95_EW1', 'Dur_2_80_EW1', 'epic_distance(km)',
#        'Hypo_dis(km)', 'Vs30', 'f0, HV'],
#       dtype='object')

# %%
ai=df1['Arias Intensity(m/s)']
dis=df1['epic_distance(km)']

# %%
plt.scatter(dis,np.log(ai))
#plt.yscale('log')
# Out:
# C:\Users\Dev\anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
a=ai.sort_values(ascending=False)
a.head(20)
# Out:
# 199719    99655.696642
# 199698    73371.186746
# 43382     63157.167217
# 199713    55943.075694
# 199709    49150.814249
# 17830     42882.301856
# 290616    39662.127941
# 199711    33450.347448
# 199700    27738.975986
# 56299     11840.175161
# 199712     9544.708451
# 354718     8873.095984
# 199710     8262.568498
# 36648      5690.528882
# 199697     5111.843946
# 354719     4778.186820
# 24410      4697.915700
# 199723     3937.523474
# 354720     3903.345513
# 199701     3733.846262
# Name: Arias Intensity(m/s), dtype: float64

# %%
df1.loc[df1['Arias Intensity(m/s)'].idxmax()]
# Out:
# EQYr                                2014
# EQMon                                  7
# EQDay                                 12
# EQHH                                   4
# EQMM                                  22
# EQSS                                   0
# EQLat                              37.05
# EQLong                            142.32
# EQDepth                               33
# EQMag                                  7
# STNCode                           MYGH05
# STNLat                           38.5793
# STNLong                           140.78
# STNH                                -278
# recYr                               2014
# recMon                                 7
# recDay                                12
# recHH                                  4
# recMM                                 22
# recSS                                 41
# fsamp                                100
# recDur                               170
# ScFactor                     0.000357727
# ...

# %%
cav=df1['CAV(m/s)']
b=cav.sort_values(ascending=False)
b.head(20)
# Out:
# 199719    611.834546
# 17830     421.225094
# 199698    385.554256
# 43382     378.685182
# 199713    376.741729
# 199711    290.577292
# 290616    275.029763
# 199709    273.857402
# 354718    220.187332
# 199700    201.508914
# 199712    184.783934
# 56299     180.630601
# 354719    129.963748
# 99628     128.964769
# 23190     128.662080
# 199723    121.441505
# 199710    120.018568
# 199707    114.285934
# 354720    111.743730
# 213104     97.598904
# Name: CAV(m/s), dtype: float64

# %%
#plt.scatter(dis,cav)

#sns.set_style("darkgrid")
plt.figure(figsize=(15,8),dpi=100)
#sns.scatterplot(dis,mag,color='black' )
plt.scatter(dis,cav)
plt.ylim([0,20])
#plt.ylabel('Magnitude(JMA)' ,fontsize=20)
#plt.xlabel('Epicentral Distance', fontsize=20)
#plt.title('Magnitude vs Epicentral Distance', fontsize=20)
#plt.legend(fontsize='25')
plt.tick_params(axis='both', which='major', labelsize=20)

# %%
df1.shape
# Out:
# (407910, 39)

# %%
df2=df1.loc[(df['epic_distance(km)'] >= 30 )&(df['epic_distance(km)'] <= 300)]

# %%
df2.shape
# Out:
# (328988, 39)

# %%
df2 = df2.rename(columns={'epic_distance(km)': 'epic_dis', 'Hypo_dis(km)': 'hypo_dis','CAV(m/s)':'CAV'})

# %%
cav=df2['CAV']
dis=df2['epic_dis']

# %%
dis.max()
# Out:
# 299.9915078617793

# %%
plt.figure(figsize=(15,8),dpi=100)
#sns.scatterplot(dis,mag,color='black' )
plt.scatter(dis,cav)
plt.ylim([0,4])
#plt.ylabel('Magnitude(JMA)' ,fontsize=20)
#plt.xlabel('Epicentral Distance', fontsize=20)
#plt.title('Magnitude vs Epicentral Distance', fontsize=20)
#plt.legend(fontsize='25')
plt.tick_params(axis='both', which='major', labelsize=20)

# %%
a1=df2[(df2.EQMag >= 4 )&(df2.EQMag <= 5 )].CAV
b1=df2[(df2.EQMag >= 4 )&(df2.EQMag <= 5 )].epic_dis
a2=df2[(df2.EQMag > 5 )&(df2.EQMag <= 6 )].CAV
b2=df2[(df2.EQMag > 5 )&(df2.EQMag <= 6 )].epic_dis
a3=df2[(df2.EQMag > 6 )&(df2.EQMag <= 7 )].CAV
b3=df2[(df2.EQMag > 6 )&(df2.EQMag <= 7 )].epic_dis
a4=df2[(df2.EQMag > 7 )].CAV
b4=df2[(df2.EQMag > 7 )].epic_dis

# %%
plt.style.use('seaborn-pastel')
sns.color_palette("rocket")
sns.set_style("darkgrid")
plt.figure(figsize=(15,8),dpi=100)
sns.scatterplot(b1,a1,color='black',label='Magnitude 4-5' )
sns.scatterplot(b2,a2,color='red', label='Magnitude 5-6' )
sns.scatterplot(b3,a3,color='blue', label='Magnitude 6-7' )
sns.scatterplot(b4,a4,color='green',label='Magnitude > 7' )
plt.legend(fontsize=15)
plt.ylim([0,0.1])

#plt.ylabel('Significant Duration(5-75)' ,fontsize=20)
#plt.xlabel('Epicentral Distance', fontsize=20)
#plt.title('Duration vs Epicentral Distance', fontsize=20)
#plt.legend(fontsize='25')
plt.tick_params(axis='both', which='major', labelsize=20)
# Out:
# C:\Users\Dev\anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(15,8),dpi=100)
sns.scatterplot(b1,a1,color='black',label='Magnitude 4-5' )
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
plt.figure(figsize=(15,8),dpi=100)
sns.scatterplot(b4,a4,color='black',label='Magnitude 4-5' )
plt.ylim([0,1])
# Out:
# (0.0, 1.0)
